# %%
import pandas as pd

# %% [markdown]
# ## Task 1- Extraction:
# 1. Change textfile to csv
# 2. Convert csv to Dataframe with column names

# %%
import csv

# %%
log_df=pd.read_csv('log.txt')
log_df=log_df.to_csv('log.csv', index=False)

# %%
log_df

# %%
log_df=pd.read_csv('log.csv', names=['task', 'status', 'trackerID', 'serverregion', 'timestamp', 'server'], delimiter='|')

# %%
log_df
# Out:
#                                        task   status    trackerID  \
# 0                    Data quality assurance  success  89328463487
# 1    Designing and implementing data models  success  89328463488
# 2      Extracting data from various sources  success  89328463489
# 3        Loading data into a data warehouse  success  89328463490
# 4                    Data quality assurance  success  89328463491
# ..                                      ...      ...          ...
# 995                         Data governance  success  89328464482
# 996         Optimizing database performance   failed  89328464483
# 997         Optimizing database performance  success  89328464484
# 998                 Building data pipelines  success  89328464485
# 999  Designing and implementing data models  success  89328464486
#
#              serverregion      timestamp  \
# 0             Florida;USA  1599093305000
# 1          Ontario;Canada  1589218599000
# 2          California;USA  1595463446000
# ...

# %%
log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   task          1000 non-null   object
#  1   status        1000 non-null   object
#  2   trackerID     1000 non-null   int64
#  3   serverregion  1000 non-null   object
#  4   timestamp     1000 non-null   int64
#  5   server        1000 non-null   object
#  6   state         1000 non-null   object
#  7   country       1000 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 62.6+ KB

# %%
log_df.columns
# Out:
# Index(['task', 'status', 'trackerID', 'serverregion', 'timestamp', 'server'], dtype='object')

# %% [markdown]
# ## Task 2 - Cleaning:
# 1. Split state and country
# 2. Change timestamp datatype to date

# %%
def my_country(text):
    result=text.split(',')[0]
    return result




def my_state(text):
    result=text.split(',')[0]
    return result

# %%
log_df['state']= log_df['serverregion'].apply(my_state)
log_df['country']= log_df['serverregion'].apply(my_country)

# %%
log_df
# Out:
#                                        task   status    trackerID  \
# 0                    Data quality assurance  success  89328463487
# 1    Designing and implementing data models  success  89328463488
# 2      Extracting data from various sources  success  89328463489
# 3        Loading data into a data warehouse  success  89328463490
# 4                    Data quality assurance  success  89328463491
# ..                                      ...      ...          ...
# 995                         Data governance  success  89328464482
# 996         Optimizing database performance   failed  89328464483
# 997         Optimizing database performance  success  89328464484
# 998                 Building data pipelines  success  89328464485
# 999  Designing and implementing data models  success  89328464486
#
#     serverregion      timestamp                                   server  \
# 0        Florida  1599093305000    464f:bdbd:1d:535a:2dad:5117:a92f:b359
# ...

# %% [markdown]
# ##### 2. Change unix timestamp to date

# %%
log_df[['timestamp']]
# Out:
#          timestamp
# 0    1599093305000
# 1    1589218599000
# 2    1595463446000
# 3    1605932487000
# 4    1587354266000
# ..             ...
# 995  1593117157000
# 996  1597399201000
# 997  1607161055000
# 998  1588130663000
# 999  1604987132000
#
# [1000 rows x 1 columns]

# %%
import datetime

# %%
log_df['date']=pd.to_datetime(log_df['timestamp'], unit='ms')

# %%
log_df
# Out:
#                                        task   status    trackerID  \
# 0                    Data quality assurance  success  89328463487
# 1    Designing and implementing data models  success  89328463488
# 2      Extracting data from various sources  success  89328463489
# 3        Loading data into a data warehouse  success  89328463490
# 4                    Data quality assurance  success  89328463491
# ..                                      ...      ...          ...
# 995                         Data governance  success  89328464482
# 996         Optimizing database performance   failed  89328464483
# 997         Optimizing database performance  success  89328464484
# 998                 Building data pipelines  success  89328464485
# 999  Designing and implementing data models  success  89328464486
#
#     serverregion      timestamp                                   server  \
# 0        Florida  1599093305000    464f:bdbd:1d:535a:2dad:5117:a92f:b359
# ...

# %%
columns = ['task', 'status', 'trackerID' ,'server', 'state', 'country', 'date']
new_manager = log_df[columns].copy()

# %%
new_manager.to_csv('managerial_review.csv')

# %% [markdown]
# ## Task 3- Analysis
# 1. What country has the most successful and failed operation

# %%
log_df[['status', 'country']]
